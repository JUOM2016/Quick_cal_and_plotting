# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter

# %%
dir = 'C:\\Users\\wj2002\\Dropbox (Heriot-Watt University Team)\\RES_EPS_Quantum_Photonics_Lab\\Experiments\\Current Experiments\\Broadband telecom quantum memories\\2022_PrYVO_Spectroscopy\\Infrared\\0_1%_Rabi'
folder = '20221205'

# %%
plot_data=['RAB12504.CSV']
path_data= dir + '\\' + folder + '\\' + plot_data[0]
data=pd.read_csv(path_data)
data=data.to_numpy() # Read the raw data when the laser is focused into the sample

fig, ax1 = plt.subplots()
ax1.plot(data[:,0]*1e6, data[:,2], 'r-', label='Transmitted signal')
ax1.plot(data[:,0]*1e6, data[:,3], 'b-', label='Reflected signal')
ax1.legend()
ax1.set_xlabel('Time [\u03BCs]')
ax1.set_ylabel('Amplitude [V]')
#ax1.set_title('The laser polarisation is perpendicular to crystal axis')
ax1.set_title('The laser polarisation is parallel to crystal axis')
fig.patch.set_facecolor('white')
